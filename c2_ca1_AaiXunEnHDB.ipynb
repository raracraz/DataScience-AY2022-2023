# %%
# Name: Aai Xun En
# Student ID: P2104089
# Class/Module Class: DISM/FT/2B/21, EL/EP0302/FT/02
# Title: Trend in the ethic groups of the residence of Singaporeans in different dwellings

# Dataset URLs: 
# https://data.gov.sg/dataset/resident-households-by-type-of-dwelling-ethnic-group-of-head-of-household-and-tenancy-2015
# https://data.gov.sg/dataset/resident-households-by-type-of-dwelling-and-age-group-of-head-of-household-2015
# https://data.gov.sg/dataset/resident-households-by-type-of-dwelling-household-size-and-ethnic-group-of-head-of-household-2015

# Naming convention: c2_ca1_[name].ipynb

# %%
import numpy as np
import matplotlib.pyplot as plt

ethnic_group = np.genfromtxt("csvDataHDB/resident-households-by-type-of-dwelling-total-ethnic-grp-of-head-of-household-tenancy.csv", delimiter=",", dtype=str, skip_header=1)
ethnic_group_list = [[],[],[]]

# generate from age group
age_group = np.genfromtxt("csvDataHDB/resident-households-by-type-of-dwelling-total-and-age-group-of-head-of-household.csv", delimiter=",", dtype=str, skip_header=1)
age_group_list = [[],[],[]]

household_size = np.genfromtxt("csvDataHDB/type-of-dwelling-broad-household-size-and-ethnic-group-of-head-of-household.csv", delimiter=",", dtype=str, skip_header=1)
household_size_list = [[],[],[]]
# Out:
# [['2015' 'Total' 'Total' '"Total"' '1225.3']
#  ['2015' 'Total' 'Total' '"HDB Dwellings"' '981.1']
#  ['2015' 'Total' 'Total' '"Condominiums And Other Apartments"' '170.8']
#  ['2015' 'Total' 'Total' '"Landed Properties"' '69.2']
#  ['2015' 'Total' 'Total' '"Others"' '4.2']
#  ['2015' 'Total' '1 Person' '"Total"' '146']
#  ['2015' 'Total' '1 Person' '"HDB Dwellings"' '117.3']
#  ['2015' 'Total' '1 Person' '"Condominiums And Other Apartments"' '24.6']
#  ['2015' 'Total' '1 Person' '"Landed Properties"' '2.9']
#  ['2015' 'Total' '1 Person' '"Others"' '1.2']
#  ['2015' 'Total' '2 Persons' '"Total"' '259.2']
#  ['2015' 'Total' '2 Persons' '"HDB Dwellings"' '214.6']
#  ['2015' 'Total' '2 Persons' '"Condominiums And Other Apartments"' '34.3']
#  ['2015' 'Total' '2 Persons' '"Landed Properties"' '9.6']
#  ['2015' 'Total' '2 Persons' '"Others"' '0.7']
#  ['2015' 'Total' '3 Persons' '"Total"' '256.2']
#  ['2015' 'Total' '3 Persons' '"HDB Dwellings"' '211.3']
# ...
